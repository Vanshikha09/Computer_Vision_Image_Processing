# %%
import string
import numpy as np
from PIL import Image
import os
from pickle import dump, load
import numpy as np
from keras.applications.xception import Xception, preprocess_input
from tensorflow.keras.utils import load_img, img_to_array
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate
from keras.models import Model, load_model
from keras.layers import Input, Dense, LSTM, Embedding, Dropout
# small library for seeing the progress of loops.
from tqdm import tqdm_notebook as tqdm
tqdm().pandas()
# Out:
# C:\Users\vansh\AppData\Local\Temp\ipykernel_8528\3294241141.py:17: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   tqdm().pandas()
# 0it [00:00, ?it/s]

# %%
# Loading a text file into memory
def load_doc(filename):
    # Opening the file as read only
    file = open(filename, 'r')
    text = file.read()
    file.close()
    return text

# get all imgs with their captions
def all_img_captions(filename):
    file = load_doc(filename)
    captions = file.split('\n')
    descriptions ={}
    for caption in captions[:-1]:
        img, caption = caption.split('\t')
        if img[:-2] not in descriptions:
            descriptions[img[:-2]] = [ caption ]
        else:
            descriptions[img[:-2]].append(caption)
    return descriptions

#Data cleaning- lower casing, removing puntuations and words containing numbers
def cleaning_text(captions):
    table = str.maketrans('','',string.punctuation)
    for img,caps in captions.items():
        for i,img_caption in enumerate(caps):

            img_caption.replace("-"," ")
            desc = img_caption.split()

            #converts to lowercase
            desc = [word.lower() for word in desc]
            #remove punctuation from each token
            desc = [word.translate(table) for word in desc]
            #remove hanging 's and a 
            desc = [word for word in desc if(len(word)>1)]
            #remove tokens with numbers in them
            desc = [word for word in desc if(word.isalpha())]
            #convert back to string

            img_caption = ' '.join(desc)
            captions[img][i]= img_caption
    return captions

def text_vocabulary(descriptions):
    # build vocabulary of all unique words
    vocab = set()

    for key in descriptions.keys():
        [vocab.update(d.split()) for d in descriptions[key]]

    return vocab

#All descriptions in one file 
def save_descriptions(descriptions, filename):
    lines = list()
    for key, desc_list in descriptions.items():
        for desc in desc_list:
            lines.append(key + '\t' + desc )
    data = "\n".join(lines)
    file = open(filename,"w")
    file.write(data)
    file.close()


# Set these path according to project folder in you system
dataset_text = "C:\\Users\\vansh\\Downloads\\Spartificial\\flickr_dataset"
dataset_images = "C:\\Users\\vansh\\Downloads\\Spartificial\\flickr_dataset\\images"

#we prepare our text data
filename = dataset_text+ "/" + "Flickr8k.token.txt"
#loading the file that contains all data
#mapping them into descriptions dictionary img to 5 captions
descriptions = all_img_captions(filename)
print("Length of descriptions =" ,len(descriptions))

#cleaning the descriptions
clean_descriptions = cleaning_text(descriptions)

#building vocabulary 
vocabulary = text_vocabulary(clean_descriptions)
print("Length of vocabulary = ", len(vocabulary))

#saving each description to file 
save_descriptions(clean_descriptions, "descriptions.txt")
# Out:
# Length of descriptions = 8092
# Length of vocabulary =  8763

# %%
def extract_features(directory):
        model = Xception( include_top=False, pooling='avg' )
        features = {}
        for img in tqdm(os.listdir(directory)):
            filename = directory + "/" + img
            image = Image.open(filename)
            image = image.resize((299,299))
            image = np.expand_dims(image, axis=0)
            #image = preprocess_input(image)
            image = image/127.5
            image = image - 1.0

            feature = model.predict(image)
            features[img] = feature
        return features

#2048 feature vector
features = extract_features(dataset_images)
dump(features, open("features.p","wb"))
# Out:
# C:\Users\vansh\AppData\Local\Temp\ipykernel_3776\1160954378.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for img in tqdm(os.listdir(directory)):
#   0%|          | 0/8091 [00:00<?, ?it/s]
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 291ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 457ms/step
# 1/1 [==============================] - 0s 454ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 435ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 455ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 440ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 434ms/step
# 1/1 [==============================] - 0s 279ms/step
# 1/1 [==============================] - 0s 435ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 478ms/step
# 1/1 [==============================] - 0s 363ms/step
# 1/1 [==============================] - 0s 380ms/step
# 1/1 [==============================] - 0s 363ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 347ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 296ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 459ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 391ms/step
# 1/1 [==============================] - 0s 423ms/step
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 0s 424ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 430ms/step
# 1/1 [==============================] - 0s 465ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 444ms/step
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 452ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 471ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 441ms/step
# 1/1 [==============================] - 0s 451ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 430ms/step
# 1/1 [==============================] - 0s 387ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 468ms/step
# 1/1 [==============================] - 0s 449ms/step
# 1/1 [==============================] - 0s 440ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 468ms/step
# 1/1 [==============================] - 0s 439ms/step
# 1/1 [==============================] - 0s 442ms/step
# 1/1 [==============================] - 0s 453ms/step
# 1/1 [==============================] - 0s 477ms/step
# 1/1 [==============================] - 0s 362ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 424ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 465ms/step
# 1/1 [==============================] - 0s 473ms/step
# 1/1 [==============================] - 0s 486ms/step
# 1/1 [==============================] - 0s 442ms/step
# 1/1 [==============================] - 0s 455ms/step
# 1/1 [==============================] - 0s 427ms/step
# 1/1 [==============================] - 0s 472ms/step
# 1/1 [==============================] - 0s 447ms/step
# 1/1 [==============================] - 0s 455ms/step
# 1/1 [==============================] - 0s 364ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 482ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 440ms/step
# 1/1 [==============================] - 0s 470ms/step
# 1/1 [==============================] - 0s 456ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 429ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 349ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 485ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 463ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 328ms/step
# 1/1 [==============================] - 0s 388ms/step
# 1/1 [==============================] - 0s 443ms/step
# 1/1 [==============================] - 0s 445ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 371ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 283ms/step
# 1/1 [==============================] - 0s 437ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 465ms/step
# 1/1 [==============================] - 0s 448ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 452ms/step
# 1/1 [==============================] - 0s 276ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 377ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 335ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 365ms/step
# 1/1 [==============================] - 0s 272ms/step
# 1/1 [==============================] - 0s 343ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 424ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 276ms/step
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 0s 237ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 246ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 294ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 349ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 424ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 290ms/step
# 1/1 [==============================] - 0s 339ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 308ms/step
# 1/1 [==============================] - 0s 381ms/step
# 1/1 [==============================] - 0s 350ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 382ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 270ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 353ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 273ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 350ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 377ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 289ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 355ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 273ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 290ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 381ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 362ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 286ms/step
# 1/1 [==============================] - 0s 373ms/step
# 1/1 [==============================] - 0s 283ms/step
# 1/1 [==============================] - 0s 283ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 366ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 357ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 286ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 365ms/step
# 1/1 [==============================] - 0s 286ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 382ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 439ms/step
# 1/1 [==============================] - 0s 349ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 356ms/step
# 1/1 [==============================] - 0s 389ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 420ms/step
# 1/1 [==============================] - 0s 292ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 369ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 438ms/step
# 1/1 [==============================] - 0s 335ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 277ms/step
# 1/1 [==============================] - 0s 362ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 324ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 377ms/step
# 1/1 [==============================] - 0s 372ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 451ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 378ms/step
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 379ms/step
# 1/1 [==============================] - 0s 491ms/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 0s 357ms/step
# 1/1 [==============================] - 0s 455ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 381ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 294ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 353ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 460ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 372ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 443ms/step
# 1/1 [==============================] - 1s 669ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 1s 665ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 353ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 301ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 373ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 477ms/step
# 1/1 [==============================] - 0s 363ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 466ms/step
# 1/1 [==============================] - 0s 296ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 1s 530ms/step
# 1/1 [==============================] - 1s 684ms/step
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 1s 689ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 357ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 1s 628ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 386ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 351ms/step
# 1/1 [==============================] - 0s 368ms/step
# 1/1 [==============================] - 0s 434ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 357ms/step
# 1/1 [==============================] - 0s 443ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 0s 308ms/step
# 1/1 [==============================] - 0s 355ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 338ms/step
# 1/1 [==============================] - 0s 428ms/step
# 1/1 [==============================] - 0s 338ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 338ms/step
# 1/1 [==============================] - 0s 353ms/step
# 1/1 [==============================] - 0s 284ms/step
# 1/1 [==============================] - 0s 443ms/step
# 1/1 [==============================] - 0s 295ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 1s 521ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 1s 664ms/step
# 1/1 [==============================] - 1s 687ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 478ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 281ms/step
# 1/1 [==============================] - 1s 511ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 289ms/step
# 1/1 [==============================] - 1s 694ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 488ms/step
# 1/1 [==============================] - 0s 379ms/step
# 1/1 [==============================] - 0s 293ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 1s 503ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 364ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 292ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 362ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 443ms/step
# 1/1 [==============================] - 0s 433ms/step
# 1/1 [==============================] - 0s 362ms/step
# 1/1 [==============================] - 1s 754ms/step
# 1/1 [==============================] - 0s 442ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 1s 748ms/step
# 1/1 [==============================] - 0s 497ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 364ms/step
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 1s 698ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 368ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 475ms/step
# 1/1 [==============================] - 0s 424ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 367ms/step
# 1/1 [==============================] - 0s 395ms/step
# 1/1 [==============================] - 0s 369ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 0s 368ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 1s 503ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 0s 431ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 440ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 497ms/step
# 1/1 [==============================] - 0s 373ms/step
# 1/1 [==============================] - 0s 496ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 471ms/step
# 1/1 [==============================] - 1s 713ms/step
# 1/1 [==============================] - 1s 675ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 436ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 1s 742ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 477ms/step
# 1/1 [==============================] - 0s 359ms/step
# 1/1 [==============================] - 1s 786ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 441ms/step
# 1/1 [==============================] - 0s 459ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 1s 521ms/step
# 1/1 [==============================] - 1s 645ms/step
# 1/1 [==============================] - 0s 428ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 1s 639ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 770ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 429ms/step
# 1/1 [==============================] - 0s 357ms/step
# 1/1 [==============================] - 0s 293ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 1s 709ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 517ms/step
# 1/1 [==============================] - 0s 363ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 1s 557ms/step
# 1/1 [==============================] - 1s 660ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 1s 559ms/step
# 1/1 [==============================] - 0s 381ms/step
# 1/1 [==============================] - 1s 534ms/step
# 1/1 [==============================] - 0s 355ms/step
# 1/1 [==============================] - 1s 747ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 451ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 738ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 349ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 1s 551ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 473ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 0s 347ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 357ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 455ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 455ms/step
# 1/1 [==============================] - 0s 387ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 308ms/step
# 1/1 [==============================] - 0s 420ms/step
# 1/1 [==============================] - 0s 455ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 358ms/step
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 445ms/step
# 1/1 [==============================] - 0s 461ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 0s 489ms/step
# 1/1 [==============================] - 0s 452ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 456ms/step
# 1/1 [==============================] - 0s 350ms/step
# 1/1 [==============================] - 1s 503ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 1s 534ms/step
# 1/1 [==============================] - 0s 439ms/step
# 1/1 [==============================] - 0s 492ms/step
# 1/1 [==============================] - 0s 482ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 1s 645ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 378ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 350ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 442ms/step
# 1/1 [==============================] - 0s 354ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 358ms/step
# 1/1 [==============================] - 0s 367ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 440ms/step
# 1/1 [==============================] - 1s 744ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 1s 713ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 378ms/step
# 1/1 [==============================] - 0s 471ms/step
# 1/1 [==============================] - 1s 527ms/step
# 1/1 [==============================] - 0s 331ms/step
# 1/1 [==============================] - 1s 520ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 326ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 1s 516ms/step
# 1/1 [==============================] - 1s 503ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 470ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 320ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 367ms/step
# 1/1 [==============================] - 0s 351ms/step
# 1/1 [==============================] - 0s 378ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 490ms/step
# 1/1 [==============================] - 0s 335ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 363ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 369ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 0s 378ms/step
# 1/1 [==============================] - 0s 457ms/step
# 1/1 [==============================] - 1s 510ms/step
# 1/1 [==============================] - 0s 421ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 450ms/step
# 1/1 [==============================] - 0s 294ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 336ms/step
# 1/1 [==============================] - 0s 382ms/step
# 1/1 [==============================] - 0s 377ms/step
# 1/1 [==============================] - 1s 628ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 456ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 0s 464ms/step
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 1s 611ms/step
# 1/1 [==============================] - 0s 438ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 439ms/step
# 1/1 [==============================] - 0s 471ms/step
# 1/1 [==============================] - 0s 356ms/step
# 1/1 [==============================] - 0s 377ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 498ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 482ms/step
# 1/1 [==============================] - 0s 381ms/step
# 1/1 [==============================] - 0s 304ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 355ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 360ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 343ms/step
# 1/1 [==============================] - 0s 378ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 385ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 349ms/step
# 1/1 [==============================] - 0s 350ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 340ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 339ms/step
# 1/1 [==============================] - 0s 350ms/step
# 1/1 [==============================] - 0s 357ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 453ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 1s 516ms/step
# 1/1 [==============================] - 0s 439ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 1s 744ms/step
# 1/1 [==============================] - 0s 296ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 339ms/step
# 1/1 [==============================] - 0s 376ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 455ms/step
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 514ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 373ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 455ms/step
# 1/1 [==============================] - 0s 470ms/step
# 1/1 [==============================] - 0s 351ms/step
# 1/1 [==============================] - 1s 691ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 356ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 424ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 327ms/step
# 1/1 [==============================] - 0s 358ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 295ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 1s 723ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 414ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 336ms/step
# 1/1 [==============================] - 0s 371ms/step
# 1/1 [==============================] - 0s 358ms/step
# 1/1 [==============================] - 0s 446ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 1s 658ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 1s 660ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 1s 518ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 428ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 1s 535ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 347ms/step
# 1/1 [==============================] - 0s 469ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 424ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 361ms/step
# 1/1 [==============================] - 0s 362ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 495ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 371ms/step
# 1/1 [==============================] - 0s 471ms/step
# 1/1 [==============================] - 1s 787ms/step
# 1/1 [==============================] - 0s 365ms/step
# 1/1 [==============================] - 1s 681ms/step
# 1/1 [==============================] - 0s 350ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 366ms/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 0s 325ms/step
# 1/1 [==============================] - 0s 382ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 312ms/step
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 323ms/step
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 293ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 0s 298ms/step
# 1/1 [==============================] - 0s 349ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 319ms/step
# 1/1 [==============================] - 0s 335ms/step
# 1/1 [==============================] - 0s 318ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 296ms/step
# 1/1 [==============================] - 0s 353ms/step
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 330ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 332ms/step
# 1/1 [==============================] - 0s 372ms/step
# 1/1 [==============================] - 0s 366ms/step
# ...
# 1/1 [==============================] - 1s 987ms/step
# 1/1 [==============================] - 1s 994ms/step
# 1/1 [==============================] - 1s 896ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 983ms/step
# 1/1 [==============================] - 1s 780ms/step
# 1/1 [==============================] - 1s 673ms/step
# 1/1 [==============================] - 1s 838ms/step
# 1/1 [==============================] - 1s 663ms/step
# 1/1 [==============================] - 1s 558ms/step
# 1/1 [==============================] - 0s 494ms/step
# 1/1 [==============================] - 0s 482ms/step
# 1/1 [==============================] - 1s 514ms/step
# 1/1 [==============================] - 1s 769ms/step
# 1/1 [==============================] - 0s 479ms/step
# 1/1 [==============================] - 1s 549ms/step
# 1/1 [==============================] - 0s 485ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 1s 963ms/step
# 1/1 [==============================] - 1s 781ms/step
# 1/1 [==============================] - 1s 863ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 952ms/step
# 1/1 [==============================] - 1s 547ms/step
# 1/1 [==============================] - 1s 787ms/step
# 1/1 [==============================] - 1s 703ms/step
# 1/1 [==============================] - 1s 921ms/step
# 1/1 [==============================] - 1s 950ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 829ms/step
# 1/1 [==============================] - 1s 798ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 945ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 922ms/step
# 1/1 [==============================] - 1s 979ms/step
# 1/1 [==============================] - 1s 938ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 746ms/step
# 1/1 [==============================] - 1s 980ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 994ms/step
# 1/1 [==============================] - 1s 927ms/step
# 1/1 [==============================] - 1s 996ms/step
# 1/1 [==============================] - 1s 982ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 780ms/step
# 1/1 [==============================] - 1s 679ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 748ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 883ms/step
# 1/1 [==============================] - 1s 762ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 702ms/step
# 1/1 [==============================] - 1s 883ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 788ms/step
# 1/1 [==============================] - 1s 808ms/step
# 1/1 [==============================] - 1s 868ms/step
# 1/1 [==============================] - 1s 747ms/step
# 1/1 [==============================] - 1s 875ms/step
# 1/1 [==============================] - 1s 922ms/step
# 1/1 [==============================] - 1s 691ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 983ms/step
# 1/1 [==============================] - 1s 790ms/step
# 1/1 [==============================] - 1s 913ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 707ms/step
# 1/1 [==============================] - 1s 786ms/step
# 1/1 [==============================] - 1s 979ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 787ms/step
# 1/1 [==============================] - 1s 691ms/step
# 1/1 [==============================] - 1s 818ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 957ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 856ms/step
# 1/1 [==============================] - 1s 939ms/step
# 1/1 [==============================] - 1s 664ms/step
# 1/1 [==============================] - 1s 686ms/step
# 1/1 [==============================] - 1s 673ms/step
# 1/1 [==============================] - 1s 676ms/step
# 1/1 [==============================] - 1s 857ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 813ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 766ms/step
# 1/1 [==============================] - 1s 630ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 966ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 642ms/step
# 1/1 [==============================] - 1s 901ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 721ms/step
# 1/1 [==============================] - 1s 959ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 904ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 729ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 947ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 880ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 943ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 681ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 855ms/step
# 1/1 [==============================] - 1s 805ms/step
# 1/1 [==============================] - 1s 637ms/step
# 1/1 [==============================] - 1s 679ms/step
# 1/1 [==============================] - 1s 878ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 976ms/step
# 1/1 [==============================] - 1s 864ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 770ms/step
# 1/1 [==============================] - 1s 819ms/step
# 1/1 [==============================] - 1s 688ms/step
# 1/1 [==============================] - 1s 706ms/step
# 1/1 [==============================] - 1s 920ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 976ms/step
# 1/1 [==============================] - 1s 827ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 801ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 732ms/step
# 1/1 [==============================] - 1s 730ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 779ms/step
# 1/1 [==============================] - 1s 961ms/step
# 1/1 [==============================] - 0s 489ms/step
# 1/1 [==============================] - 1s 505ms/step
# 1/1 [==============================] - 1s 553ms/step
# 1/1 [==============================] - 1s 901ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 961ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 687ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 706ms/step
# 1/1 [==============================] - 1s 746ms/step
# 1/1 [==============================] - 1s 870ms/step
# 1/1 [==============================] - 1s 742ms/step
# 1/1 [==============================] - 1s 987ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 612ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 879ms/step
# 1/1 [==============================] - 1s 912ms/step
# 1/1 [==============================] - 1s 915ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 983ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 524ms/step
# 1/1 [==============================] - 1s 507ms/step
# 1/1 [==============================] - 1s 547ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 505ms/step
# 1/1 [==============================] - 1s 648ms/step
# 1/1 [==============================] - 0s 470ms/step
# 1/1 [==============================] - 0s 444ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 641ms/step
# 1/1 [==============================] - 1s 778ms/step
# 1/1 [==============================] - 1s 660ms/step
# 1/1 [==============================] - 1s 611ms/step
# 1/1 [==============================] - 1s 802ms/step
# 1/1 [==============================] - 1s 665ms/step
# 1/1 [==============================] - 1s 829ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 561ms/step
# 1/1 [==============================] - 1s 728ms/step
# 1/1 [==============================] - 1s 548ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 0s 492ms/step
# 1/1 [==============================] - 0s 487ms/step
# 1/1 [==============================] - 1s 634ms/step

# %%
features = load(open("features.p","rb"))

# %%
#load the data 
def load_photos(filename):
    file = load_doc(filename)
    photos = file.split("\n")[:-1]
    return photos


def load_clean_descriptions(filename, photos): 
    #loading clean_descriptions
    file = load_doc(filename)
    descriptions = {}
    for line in file.split("\n"):

        words = line.split()
        if len(words)<1 :
            continue

        image, image_caption = words[0], words[1:]

        if image in photos:
            if image not in descriptions:
                descriptions[image] = []
            desc = '<start> ' + " ".join(image_caption) + ' <end>'
            descriptions[image].append(desc)

    return descriptions


def load_features(photos):
    #loading all features
    all_features = load(open("features.p","rb"))
    #selecting only needed features
    features = {k:all_features[k] for k in photos}
    return features


filename = dataset_text + "/" + "Flickr_8k.trainImages.txt"

#train = loading_data(filename)
train_imgs = load_photos(filename)
train_descriptions = load_clean_descriptions("descriptions.txt", train_imgs)
train_features = load_features(train_imgs)

# %%
#converting dictionary to clean list of descriptions
def dict_to_list(descriptions):
    all_desc = []
    for key in descriptions.keys():
        [all_desc.append(d) for d in descriptions[key]]
    return all_desc

#creating tokenizer class 
#this will vectorise text corpus
#each integer will represent token in dictionary

from keras.preprocessing.text import Tokenizer

def create_tokenizer(descriptions):
    desc_list = dict_to_list(descriptions)
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(desc_list)
    return tokenizer

# give each word an index, and store that into tokenizer.p pickle file
tokenizer = create_tokenizer(train_descriptions)
dump(tokenizer, open('tokenizer.p', 'wb'))
vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 7577

# %%
#calculate maximum length of descriptions
def max_length(descriptions):
    desc_list = dict_to_list(descriptions)
    return max(len(d.split()) for d in desc_list)
    
max_length = max_length(descriptions)
max_length
# Out:
# 32

# %%
#create input-output sequence pairs from the image description.

#data generator, used by model.fit_generator()
def data_generator(descriptions, features, tokenizer, max_length):
    while 1:
        for key, description_list in descriptions.items():
            #retrieve photo features
            feature = features[key][0]
            input_image, input_sequence, output_word = create_sequences(tokenizer, max_length, description_list, feature)
            yield [[input_image, input_sequence], output_word]

def create_sequences(tokenizer, max_length, desc_list, feature):
    X1, X2, y = list(), list(), list()
    # walk through each description for the image
    for desc in desc_list:
        # encode the sequence
        seq = tokenizer.texts_to_sequences([desc])[0]
        # split one sequence into multiple X,y pairs
        for i in range(1, len(seq)):
            # split into input and output pair
            in_seq, out_seq = seq[:i], seq[i]
            # pad input sequence
            in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
            # encode output sequence
            out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
            # store
            X1.append(feature)
            X2.append(in_seq)
            y.append(out_seq)
    return np.array(X1), np.array(X2), np.array(y)

#You can check the shape of the input and output for your model
[a,b],c = next(data_generator(train_descriptions, features, tokenizer, max_length))
a.shape, b.shape, c.shape
#((47, 2048), (47, 32), (47, 7577))
# Out:
# ((47, 2048), (47, 32), (47, 7577))

# %%
from keras.layers import Concatenate, Dense, LSTM, Input, concatenate

# %%
from keras.utils import plot_model

# define the captioning model
def define_model(vocab_size, max_length):

    # features from the CNN model squeezed from 2048 to 256 nodes
    inputs1 = Input(shape=(2048, ))
    fe1 = Dropout(0.5)(inputs1)
    fe2 = Dense(256, activation='relu')(fe1)

    # LSTM sequence model
    inputs2 = Input(shape=(max_length,))
    se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
    se2 = Dropout(0.5)(se1)
    se3 = LSTM(256)(se2)

    # Merging both models
    decoder1 = concatenate([fe2, se3])
    decoder2 = Dense(256, activation='relu')(decoder1)
    outputs = Dense(vocab_size, activation='softmax')(decoder2)

    # tie it together [image, seq] [word]
    model = Model(inputs=[inputs1, inputs2], outputs=outputs)
    model.compile(loss='categorical_crossentropy', optimizer='adam')

    # summarize model
    print(model.summary())
    plot_model(model, to_file='model.png', show_shapes=True)

    return model

# %%
# train our model
print('Dataset: ', len(train_imgs))
print('Descriptions: train=', len(train_descriptions))
print('Photos: train=', len(train_features))
print('Vocabulary Size:', vocab_size)
print('Description Length: ', max_length)
# Out:
# Dataset:  6000
# Descriptions: train= 6000
# Photos: train= 6000
# Vocabulary Size: 7577
# Description Length:  32

# %%
model = define_model(vocab_size, max_length)
epochs = 10
steps = len(train_descriptions)
# making a directory models to save our models
os.mkdir("models")
for i in range(epochs):
    generator = data_generator(train_descriptions, train_features, tokenizer, max_length)
    model.fit_generator(generator, epochs=1, steps_per_epoch= steps, verbose=1)
    model.save("models/model_" + str(i) + ".h5")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_42 (InputLayer)          [(None, 32)]         0           []
#
#  input_41 (InputLayer)          [(None, 2048)]       0           []
#
#  embedding_19 (Embedding)       (None, 32, 256)      1939712     ['input_42[0][0]']
#
#  dropout_38 (Dropout)           (None, 2048)         0           ['input_41[0][0]']
#
#  dropout_39 (Dropout)           (None, 32, 256)      0           ['embedding_19[0][0]']
#
#  dense_19 (Dense)               (None, 256)          524544      ['dropout_38[0][0]']
#
#  lstm_19 (LSTM)                 (None, 256)          525312      ['dropout_39[0][0]']
#
#  concatenate (Concatenate)      (None, 512)          0           ['dense_19[0][0]',
#                                                                   'lstm_19[0][0]']
#
#  dense_20 (Dense)               (None, 256)          131328      ['concatenate[0][0]']
#
#  dense_21 (Dense)               (None, 7577)         1947289     ['dense_20[0][0]']
#
# ==================================================================================================
# Total params: 5,068,185
# Trainable params: 5,068,185
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
# C:\Users\vansh\AppData\Local\Temp\ipykernel_3776\1199930123.py:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(generator, epochs=1, steps_per_epoch= steps, verbose=1)
# 6000/6000 [==============================] - 16913s 3s/step - loss: 4.4992
# 6000/6000 [==============================] - 13238s 2s/step - loss: 3.6591
# 6000/6000 [==============================] - 11311s 2s/step - loss: 3.3724
# 6000/6000 [==============================] - 11310s 2s/step - loss: 3.1991
# 6000/6000 [==============================] - 18098s 3s/step - loss: 3.0836
# 6000/6000 [==============================] - 26042s 4s/step - loss: 2.9965
# 6000/6000 [==============================] - 11028s 2s/step - loss: 2.9247
# 6000/6000 [==============================] - 11370s 2s/step - loss: 2.8701
# 6000/6000 [==============================] - 11548s 2s/step - loss: 2.8238
# 6000/6000 [==============================] - 11734s 2s/step - loss: 2.7895

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import argparse

ap = argparse.ArgumentParser()
ap.add_argument('-i', '--image', required=True, help="Image Path")
args = vars(ap.parse_args(['-i','']))
img_path = args['image']

#filename= dataset_text+ "/" + 'flickr_dataset\images'
def extract_features(filename, model):
        try:
            image = Image.open(filename)

        except:
            print("ERROR: Couldn't open image! Make sure the image path and extension is correct")
        image = image.resize((299,299))
        image = np.array(image)
        # for images that has 4 channels, we convert them into 3 channels
        if image.shape[2] == 4: 
            image = image[..., :3]
        image = np.expand_dims(image, axis=0)
        image = image/127.5
        image = image - 1.0
        feature = model.predict(image)
        return feature

def word_for_id(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
        if index == integer:
            return word
    return None


def generate_desc(model, tokenizer, photo, max_length):
    in_text = 'start'
    for i in range(max_length):
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        sequence = pad_sequences([sequence], maxlen=max_length)
        pred = model.predict([photo,sequence], verbose=0)
        pred = np.argmax(pred)
        word = word_for_id(pred, tokenizer)
        if word is None:
            break
        in_text += ' ' + word
        if word == 'end':
            break
    return in_text


#path = 'Flicker8k_Dataset/111537222_07e56d5a30.jpg'
max_length = 32
tokenizer = load(open("tokenizer.p","rb"))
model = load_model('flickr_dataset/models/model_9.h5')
xception_model = Xception(include_top=False, pooling="avg")

photo = extract_features(img_path, xception_model)
img = Image.open(img_path)

description = generate_desc(model, tokenizer, photo, max_length)
print("\n\n")
print(description)
plt.imshow(img)
